# %%
# Usability Score Regression Model Summary

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
from scipy.optimize import nnls

# Load and preprocess evaluation data
eval_df = pd.read_csv('../eval/uicrit/uicrit_eval_results_gradcam.csv')

# Transform metrics
eval_df['entropy_score'] = 1 - eval_df['entropy'] / 10
eval_df['clusters_score'] = 1 / (1 + eval_df['num_clusters'])
cog_x = eval_df['center_of_gravity_x']
cog_y = eval_df['center_of_gravity_y']
eval_df['center_of_gravity_score'] = 1 - np.minimum(np.sqrt((cog_x - 0.5)**2 + (cog_y - 0.5)**2) / 0.71, 1)

# Use normalized transformed features
X = eval_df[[
    'entropy_score',
    'clusters_score',
    'center_of_gravity_score',
    'symmetry_score',
    'visual_coverage',
    'placement_score']]
y = eval_df['usability_rating']

results = {}

# Dummy Regressor
dummy = DummyRegressor(strategy='mean')
dummy.fit(X, y)
y_dummy = dummy.predict(X)
results['Dummy'] = {
    'rmse': np.sqrt(mean_squared_error(y, y_dummy)),
    'corr': 0
}

# Linear Regression
lr = LinearRegression()
lr.fit(X, y)
y_lr = lr.predict(X)
results['LinearRegression'] = {
    'rmse': np.sqrt(mean_squared_error(y, y_lr)),
    'corr': pearsonr(y, y_lr)[0]
}

# NNLS
X_np = X.to_numpy()
y_np = y.to_numpy()
weights_nnls, _ = nnls(X_np, y_np)
y_nnls = np.dot(X_np, weights_nnls)
results['NNLS'] = {
    'rmse': np.sqrt(mean_squared_error(y, y_nnls)),
    'corr': pearsonr(y, y_nnls)[0]
}

# Ridge Regression
ridge = Ridge(alpha=0.1, positive=True)
ridge.fit(X, y)
y_ridge = ridge.predict(X)
results['RidgeRegression'] = {
    'rmse': np.sqrt(mean_squared_error(y, y_ridge)),
    'corr': pearsonr(y, y_ridge)[0]
}

# Random Forest
rf = RandomForestRegressor(n_estimators=100, max_depth=5, random_state=42)
rf.fit(X, y)
y_rf = rf.predict(X)
results['RandomForest'] = {
    'rmse': np.sqrt(mean_squared_error(y, y_rf)),
    'corr': pearsonr(y, y_rf)[0]
}

# Gradient Boosting
gbr = GradientBoostingRegressor(n_estimators=100, max_depth=5, random_state=42)
gbr.fit(X, y)
y_gbr = gbr.predict(X)
results['GradientBoosting'] = {
    'rmse': np.sqrt(mean_squared_error(y, y_gbr)),
    'corr': pearsonr(y, y_gbr)[0]
}

# Show results
print("📊 Model Comparison Summary:")
for model, metrics in results.items():
    print(f"{model:<20} → RMSE: {metrics['rmse']:.3f}, Correlation: {metrics['corr']:.3f}")

# Bar chart of correlations
import matplotlib.pyplot as plt
import seaborn as sns

model_names = list(results.keys())
correlations = [metrics['corr'] for metrics in results.values()]
rmses = [metrics['rmse'] for metrics in results.values()]

plt.figure(figsize=(8, 4))
sns.barplot(x=model_names, y=correlations, hue=model_names, palette='Blues_d', dodge=False, legend=False)
plt.title("Model Correlation with Expert Usability Ratings")
plt.ylabel("Pearson Correlation")
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True, axis='y')
plt.show()

plt.figure(figsize=(8, 4))
sns.barplot(x=model_names, y=rmses, hue=model_names, palette='Reds_d', dodge=False, legend=False)
plt.title("Model RMSE on Usability Ratings")
plt.ylabel("Root Mean Squared Error")
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True, axis='y')
plt.show()

# Feature importances
rf_importance = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
gbr_importance = pd.Series(gbr.feature_importances_, index=X.columns).sort_values(ascending=False)

print("🧠 Random Forest Feature Importance:")
print(rf_importance)

print("🧠 Gradient Boosting Feature Importance:")
print(gbr_importance)
# Out:
# 📊 Model Comparison Summary:
# Dummy                → RMSE: 0.643, Correlation: 0.000
# LinearRegression     → RMSE: 0.640, Correlation: 0.103
# NNLS                 → RMSE: 0.683, Correlation: -0.020
# RidgeRegression      → RMSE: 0.643, Correlation: 0.015
# RandomForest         → RMSE: 0.586, Correlation: 0.553
# GradientBoosting     → RMSE: 0.356, Correlation: 0.899
# 🧠 Random Forest Feature Importance:
# entropy_score              0.299739
# visual_coverage            0.176278
# symmetry_score             0.154134
# placement_score            0.135414
# center_of_gravity_score    0.127231
# clusters_score             0.107203
# dtype: float64
# 🧠 Gradient Boosting Feature Importance:
# entropy_score              0.224156
# visual_coverage            0.200787
# symmetry_score             0.163173
# center_of_gravity_score    0.161063
# placement_score            0.146819
# clusters_score             0.104002
# dtype: float64
